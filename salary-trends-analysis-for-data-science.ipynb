# %% [markdown]
# <a href="https://www.kaggle.com/code/kashish2407/salary-trends-analysis-for-data-science?scriptVersionId=213816264" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>Welcome  <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">To my  <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Notebook </strong></strong></strong></h1></header>

# %% [markdown]
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>DS <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">Salary <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Trends </strong></strong></strong></h1></header>
# <div style="background-color:white;font-size:20px;font-family:Verdana;border-style: solid;border-color: #AF0171;border-width:4px;padding:10px;margin: 1px;color:#240A34;overflow:hidden">
# The field of Data Science has experienced remarkable growth in recent years, establishing itself as one of the most in-demand career paths worldwide. As organizations increasingly rely on data-driven decision-making, the need for skilled data professionals has surged. This expansion has not only generated a wealth of job opportunities but also highlighted significant salary variations based on factors such as location, experience, and job roles.</div>

# %% [markdown]
# # <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️About the Dataset🗒️</div>
# <p>
#     This analysis is based on the dataset <strong>"Data Science Salary 2020 to 2024"</strong>, which offers comprehensive insights into the earnings of data science professionals over three years. The dataset includes key features summarized in the table below:
# </p>
#
# <table>
#     <tr>
#         <th>Feature</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td>🗓️ <strong>work_year</strong></td>
#         <td>The year in which the salary was recorded (2020,2021, 2022, 2023, or 2024).</td>
#     </tr>
#     <tr>
#         <td>🎓 <strong>experience_level</strong></td>
#         <td>The professional's level of experience (e.g., Entry-level, Mid-level, Senior, or Executive).</td>
#     </tr>
#     <tr>
#         <td>💼 <strong>employment_type</strong></td>
#         <td>The nature of the employment (Full-time, Part-time, Contract, etc.).</td>
#     </tr>
#     <tr>
#         <td>🏷️ <strong>job_title</strong></td>
#         <td>The job title (e.g., Data Scientist, Data Engineer, Machine Learning Engineer).</td>
#     </tr>
#     <tr>
#         <td>💰 <strong>salary</strong></td>
#         <td>The reported salary in the local currency.</td>
#     </tr>
#     <tr>
#         <td>🌍 <strong>salary_currency</strong></td>
#         <td>The currency in which the salary was reported.</td>
#     </tr>
#     <tr>
#         <td>💵 <strong>salary_in_usd</strong></td>
#         <td>The salary converted to USD for standardization.</td>
#     </tr>
#     <tr>
#         <td>📍 <strong>company_location</strong></td>
#         <td>The geographical location of the employer.</td>
#     </tr>
#     <tr>
#         <td>🏢 <strong>company_size</strong></td>
#         <td>The size of the company (Small, Medium, or Large).</td>
#     </tr>
# </table>
#
# # <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Objective</div>
# <p>
#     The goal of this notebook is to explore and extract actionable insights from the dataset, addressing the following key questions:
# </p>
# <table>
#     <tr>
#         <th>Key Questions</th>
#     </tr>
#     <tr>
#         <td>📊 What are the salary trends across the years 2020 to 2024?</td>
#     </tr>
#     <tr>
#         <td>👩‍💻 How do salaries differ by job titles and levels of experience?</td>
#     </tr>
#     <tr>
#         <td>🌎 What regional trends can be observed in data science salaries?</td>
#     </tr>
#     <tr>
#         <td>🏢 How does company size influence compensation in this field?</td>
#     </tr>
#     <tr>
#         <td>🏆 Which roles and locations offer the highest earning potential?</td>
#     </tr>
# </table>
#
# <p>
#     By analyzing these aspects, this notebook aims to provide a comprehensive understanding of the data science job market, offering valuable insights for both aspiring professionals and industry veterans.
# </p>

# %% [markdown]
# #  <header><h1 style="color:#4C0033;font-size:60px;font-family:Verdana;text-align:center;"><strong>Understand <strong style="color:#AF0171;font-size:40px;font-family:Verdana;">Data <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;"> Trends </strong></strong></strong></h1></header>
#
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Import Necessary LibLibraries 🗒️</div>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

import os
import warnings
warnings.filterwarnings('ignore')
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/latest-data-science-job-salaries-2024/DataScience_salaries_2024.csv
# /kaggle/input/data-science-salary-2021-to-2023/Data Science Salary 2021 to 2023.csv
# /kaggle/input/data-science-jobs-and-salary-glassdoor/glassdoor_jobs.csv
# /kaggle/input/data-science-jobs-and-salary-glassdoor/Glassdoor_Salary_Cleaned_Version.csv

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Load Dataset 🗒️</div>

# %%
main_df= pd.read_csv("/kaggle/input/latest-data-science-job-salaries-2024/DataScience_salaries_2024.csv")

# %%
df=main_df.copy()
df
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Explore Dataset 🗒️</div>

# %%
df.shape
# Out:
# (14838, 11)

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>Data <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">Preprocessing <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Steps </strong></strong></strong></h1></header>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Drop Irrelevant Features 🗒️</div>

# %%
df.drop(columns=['salary','salary_currency'], axis =1 , inplace= True)

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Check for Data type 🗒️</div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary_in_usd       14838 non-null  int64
#  5   employee_residence  14838 non-null  object
#  6   remote_ratio        14838 non-null  int64
#  7   company_location    14838 non-null  object
#  8   company_size        14838 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Categorical and Numerical Data Split🗒️</div>

# %%
cat_data= df.select_dtypes(include =['object'])
cat_col=cat_data.columns
num_data= df.select_dtypes(include =['int64'])
num_col=num_data.columns

# %% [markdown]
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>Performing <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">Basic <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Statistics </strong></strong></strong></h1></header>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Check for Basic Statistic 🗒️</div>

# %%
cat_data.describe().T
# Out:
#                     count unique            top   freq
# experience_level    14838      4             SE   9696
# employment_type     14838      4             FT  14772
# job_title           14838    153  Data Engineer   3162
# employee_residence  14838     88             US  12926
# company_location    14838     77             US  12975
# company_size        14838      3              M  13674

# %%
num_data.describe()
# Out:
#           work_year  salary_in_usd  remote_ratio
# count  14838.000000   14838.000000  14838.000000
# mean    2023.138900  149874.718763     32.760480
# std        0.700799   69009.181349     46.488278
# min     2020.000000   15000.000000      0.000000
# 25%     2023.000000  102000.000000      0.000000
# 50%     2023.000000  141300.000000      0.000000
# 75%     2024.000000  185900.000000    100.000000
# max     2024.000000  800000.000000    100.000000

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Check Missing Data 🗒️</div>

# %%
def missing(df):
    miss = pd.DataFrame(columns=['Column', 'Value', 'Percentage'])  # Initialize the DataFrame
    for col in df.columns:
        value = df[col].isnull().sum()
        percentage = (value / len(df)) * 100
        new_row = pd.DataFrame({'Column': [col], 'Value': [value], 'Percentage': [percentage]})
        miss = pd.concat([miss, new_row], ignore_index=True)  # Use pd.concat instead of .append
    return miss

# %%
missing(df)
# Out:
#                Column Value  Percentage
# 0           work_year     0         0.0
# 1    experience_level     0         0.0
# 2     employment_type     0         0.0
# 3           job_title     0         0.0
# 4       salary_in_usd     0         0.0
# 5  employee_residence     0         0.0
# 6        remote_ratio     0         0.0
# 7    company_location     0         0.0
# 8        company_size     0         0.0

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(),cbar=True,    cbar_kws={'label': 'Missing Data'},  cmap= 'rocket')
plt.title("Missing Data Heatmap", fontsize=16)
plt.show()

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Check for Duplicates 🗒️</div>

# %%
df.duplicated().sum()
# Out:
# 5711

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Check Number of unique values Features have 🗒️</div>

# %%
for col in df.columns:
    print('⭕'*30)
    print(f"{col} has {df[col].nunique()} unique values")
    
    print()
# Out:
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# work_year has 5 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# experience_level has 4 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# employment_type has 4 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# job_title has 153 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# salary_in_usd has 2730 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# employee_residence has 88 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# remote_ratio has 3 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# company_location has 77 unique values
#
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
# company_size has 3 unique values

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Check for Value Counts of Each Columns 🗒️</div>

# %%
for col in df.columns:
    print('🔖'*30)
    print(f'The Value Count for {col}')
    print(df[col].value_counts())
# Out:
# 🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖
# The Value Count for work_year
# work_year
# 2023    8519
# 2024    4374
# 2022    1652
# 2021     218
# 2020      75
# Name: count, dtype: int64
# 🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖
# The Value Count for experience_level
# experience_level
# SE    9696
# MI    3553
# EN    1148
# EX     441
# Name: count, dtype: int64
# 🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖
# The Value Count for employment_type
# employment_type
# FT    14772
# PT       27
# CT       26
# FL       13
# Name: count, dtype: int64
# 🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖🔖
# The Value Count for job_title
# job_title
# Data Engineer                      3162
# Data Scientist                     3015
# Data Analyst                       2189
# Machine Learning Engineer          1542
# Research Scientist                  475
#                                    ...
# Deep Learning Researcher              1
# Big Data Developer                    1
# AWS Data Architect                    1
# ...

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Transform Names  🗒️</div>

# %%
df['experience_level'] = df['experience_level'].replace('EN','Junior')
df['experience_level'] = df['experience_level'].replace('MI','Intermediate')
df['experience_level'] = df['experience_level'].replace('SE','Expert')
df['experience_level'] = df['experience_level'].replace('EX','Director')

df['employment_type'] = df['employment_type'].replace('PT','Part_time')
df['employment_type'] = df['employment_type'].replace('FT','Full_time')
df['employment_type'] = df['employment_type'].replace('CT','Contract')
df['employment_type'] = df['employment_type'].replace('FL','Freelance')

df['company_size'] = df['company_size'].replace('S','Small')
df['company_size'] = df['company_size'].replace('M','Medium')
df['company_size'] = df['company_size'].replace('L','Large')

df
# Out:
#        work_year experience_level employment_type  \
# 0           2021     Intermediate       Full_time
# 1           2021     Intermediate       Full_time
# 2           2020     Intermediate       Full_time
# 3           2021     Intermediate       Full_time
# 4           2022           Expert       Full_time
# ...          ...              ...             ...
# 14833       2022     Intermediate       Full_time
# 14834       2020         Director       Full_time
# 14835       2021           Junior       Full_time
# 14836       2022           Junior       Full_time
# 14837       2020           Junior       Part_time
#
#                              job_title  salary_in_usd employee_residence  \
# 0                       Data Scientist          40038                 CL
# 1                      BI Data Analyst          36259                 HU
# 2                       Data Scientist          35735                 HU
# ...

# %% [markdown]
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>Exploratory <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">Data <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Analysis </strong></strong></strong></h1></header>
# <hr style="border-color:#EE6983;border-style: dashed;border-width:2px;" >
# <br>
#
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>Performing <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">Univariate <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Analysis </strong></strong></strong></h1></header>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️On Experiences Level  🗒️</div>

# %%
# for col in (cat_col):
counts = df['experience_level'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='experience_level', palette='rocket', order=top_categories)
plt.title(f"Distribution of Experience Level", fontsize=20)
# plt.xticks(rotation=45)
plt.xlabel('experience_level', fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#     <li><strong>Dominance of Experts:</strong> Experts represent the largest group in the dataset, indicating that the majority of individuals are highly experienced. This could suggest a higher demand for seasoned professionals or a trend toward hiring individuals with substantial prior experience.</li>
#
#   </ul>
# </div>

# %%
counts = df['experience_level'].value_counts()
top_categories = counts.head(10)
plt.figure(figsize=(8,8))
plt.pie(top_categories , labels = top_categories.index , 
        autopct = '%1.1f%%',startangle=90,colors=plt.cm.tab10.colors)
plt.title(f"Distribution of experience_level", fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #3498db; border-radius: 10px; padding: 15px; background-color: #f8f9fa; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #3498db; text-align: center;">Observations</h3>
#   <ul>
#     <li><strong>Experts Dominate:</strong> Experts constitute the majority, making up <strong>65.3%</strong> of the dataset. This indicates a heavy emphasis on hiring seasoned professionals in the field.</li>
#     <li><strong>Intermediate Representation:</strong> Professionals with an intermediate level of experience account for <strong>23.9%</strong>, making them the second-largest group.</li>
#     <li><strong>Junior Professionals:</strong> Juniors form <strong>7.7%</strong> of the dataset, showcasing a relatively small proportion of entry-level opportunities.</li>
#     <li><strong>Minimal Representation of Directors:</strong> Directors represent the smallest segment, with only <strong>3.0%</strong>. This highlights the exclusivity of leadership roles in the domain.</li>
#   </ul>
# </div>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️On Job Title  🗒️</div>

# %%
counts = df['job_title'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='job_title', palette='rocket',orient ='v', order=top_categories)
plt.title(f"Top 10 Categories of Experience Level", fontsize=20)
plt.ylabel('Job Title ', fontsize=14)
plt.xlabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #3498db; border-radius: 10px; padding: 15px; background-color: #f8f9fa; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #3498db; text-align: center;">Observations</h3>
#   <ul>
#     <li><strong>Data Engineers Lead the Field:</strong>  Data Engineers are the most prevalent, playing a critical role in managing and structuring data pipelines essential for organizational success.</li>
#     <li><strong>Data Scientists Close Second:</strong> Data Scientists hold the second position, emphasizing their role in analyzing and deriving insights from data.</li>
#
#
# <li><strong>Strong Representation of Data Analysts:</strong> Data Analysts rank third, highlighting their importance in interpreting data trends and supporting decision-making.</li>
#     <li><strong>Machine Learning Engineers Feature Prominently:</strong> Machine Learning Engineers are in fourth place, reflecting the growing demand for deploying predictive systems.</li>
#     <li><strong>Other Specialized Roles: </strong> Research Scientists, Analytics Engineers, and Applied Scientists follow, indicating niche expertise within data science.</li>
#   </ul>
# </div>

# %% [markdown]
# <hr style="border-color:#640D5F;border-style: dashed;border-width:2px;" >

# %%
counts = df['job_title'].value_counts()
top_categories = counts.head(10)
plt.figure(figsize=(8,8))
plt.pie(top_categories , labels = top_categories.index , 
        autopct = '%1.1f%%')
plt.title(f"Distribution of Job Titles", fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #3498db; border-radius: 10px; padding: 15px; background-color: #f8f9fa; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #3498db; text-align: center;">Observations</h3>
#   <ol>
#       <li><strong>Top Three Job Titles:</strong></li>
#       <ul>
#         <li>Data Engineer is the largest category, representing <strong>26.3%</strong> of the total.</li>
#         <li><span class="highlight">Data Scientist</span> follows closely, accounting for <strong>25.0%</strong>.</li>
#         <li><span class="highlight">Data Analyst</span> makes up <strong>18.2%</strong>, completing the top three roles.</li>
#     </ul>
#
#
#
#
# <li><strong>Strong Representation of Data Analysts:</strong> Data Analysts rank third, highlighting their importance in interpreting data trends and supporting decision-making.</li>
#     <li><strong>Machine Learning Engineers Feature Prominently:</strong> Machine Learning Engineers are in fourth place, reflecting the growing demand for deploying predictive systems.</li>
#     <li><strong>Other Specialized Roles: </strong> Research Scientists, Analytics Engineers, and Applied Scientists follow, indicating niche expertise within data science.</li>
#   </ul>
# </div>

# %% [markdown]
# <hr style="border-color:#640D5F;border-style: dashed;border-width:2px;" >

# %%
from wordcloud import WordCloud
import nltk

def Freq_df(cleanwordlist):
    Freq_dist_nltk = nltk.FreqDist(cleanwordlist)
    df_freq = pd.DataFrame.from_dict(Freq_dist_nltk, orient='index')
    df_freq.columns = ['Frequency']
    df_freq.index.name = 'Term'
    df_freq = df_freq.sort_values(by=['Frequency'],ascending=False)
    df_freq = df_freq.reset_index()
    return df_freq
def Word_Cloud (data, title):
    wordcloud = WordCloud(
        width=1200, 
        height=600,
        max_words=50,
        max_font_size=100,
        background_color='white', 
        colormap='rocket', 
        collocations=False
    ).generate_from_frequencies(data)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off') 
    plt.title(title, fontsize=20)
    plt.show()

# %%
freq_df = Freq_df(df['job_title'].values.tolist())
data = dict(zip(freq_df['Term'].tolist(), freq_df['Frequency'].tolist()))
data = freq_df.set_index('Term').to_dict()['Frequency']

Word_Cloud(data ,'WordCloud of job titles')

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#     <li><strong>Core Roles (Data Scientist, Data Engineer, Data Analyst)</strong>  dominate in both visualizations, emphasizing their importance (~70% in the pie chart).</li>
#      <li><strong>Specialized Roles (Machine Learning Engineer, Research Scientist) </strong> are moderately represented, reflecting growing demand.</li>
#       <li><strong>Niche Roles (AI Engineer, Data Product Manager)</strong> appear in smaller fonts, signaling emerging trends.</li>
#
#   </ul>
#   <hr style="border-color:#4CAF50;border-style: dotted;border-width:2px;" >
#    <h3 style="color: #4CAF50; text-align: center;">Career Suggestions</h3>
#   <ol>
#     <li><strong>Focus on Core Roles: </strong>  Start with Data Scientist, Data Engineer, or Data Analyst roles for broad applicability..</li>
#      <li><strong>Move into Specialized Roles: </strong> Transition to Machine Learning Engineer or Research Scientist with expertise in AI or deep learning.</li>
#       <li><strong>Explore Emerging Roles: </strong> Consider AI Engineer or Data Product Manager for future-forward career paths.</li>
#
#   </ol>
# </div>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️On Employment Type 🗒️</div>

# %%
counts = df['employment_type'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='employment_type', palette='rocket', order=top_categories)
plt.title(f"Distribution of Employment type", fontsize=20)
# plt.xticks(rotation=45)
plt.xlabel('employment_type', fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>The bar chart shows that full-time employment overwhelmingly dominates, with over 14,000 roles, while part-time, contract, and freelance roles are minimally represented. This suggests that most data-related jobs prioritize stability and long-term commitments, with limited flexibility for alternative arrangements.</li>
#   </ul>

# %% [markdown]
# <hr style="border-color:#640D5F;border-style: dashed;border-width:2px;" >

# %%
counts = df['employment_type'].value_counts()
top_categories = counts.head(10)
plt.figure(figsize=(8,8))
plt.pie(top_categories , labels = top_categories.index , 
        autopct = '%1.1f%%',startangle=90,colors=plt.cm.tab10.colors)
plt.title(f"Distribution of Employment type", fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️On Employee Residence & Company Location 🗒️</div>

# %%
counts = df['company_location'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='company_location', palette='rocket',orient ='v', order=top_categories)
plt.title(f"Top 10 Categories of Company Location", fontsize=20)
plt.ylabel('Company Location', fontsize=14)
plt.xlabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <hr style="border-color:#640D5F;border-style: dashed;border-width:2px;" >

# %%
counts = df['employee_residence'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='employee_residence', palette='rocket',orient ='v', order=top_categories)
plt.title(f"Top 10 Categories of Employee Residence", fontsize=20)
plt.ylabel('Employee Residence ', fontsize=14)
plt.xlabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       The charts highlight that the US is the dominant location for both companies and employees, followed by UK and Canada. European countries like Spain, Germany, and France also appear but with smaller contributions. The trends are similar for company locations and employee residences, suggesting that most employees are based in the same regions as their companies, with limited remote work or regional hiring being predominant. The global presence, including countries from Asia (India) and Oceania (Australia), reflects a diverse but US-centric distribution.
#   </ul>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️On Company Size🗒️</div>

# %%
counts = df['company_size'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='company_size', palette='rocket',orient ='v', order=top_categories)
plt.title(f"Distribution of company_size", fontsize=20)
plt.ylabel('company_size', fontsize=14)
plt.xlabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <hr style="border-color:#640D5F;border-style: dashed;border-width:2px;" >

# %%
counts = df['company_size'].value_counts()
top_categories = counts.head(10)
plt.figure(figsize=(8,8))
plt.pie(top_categories , labels = top_categories.index , 
        autopct = '%1.1f%%',startangle=90,colors=plt.cm.tab10.colors)
plt.title(f"Distribution of company_size", fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>Dominance of Medium-Sized Companies: The majority (92.2%) of records are from medium-sized companies, indicating their significant representation in the dataset.</li>
#       <li>Smaller Presence of Large Companies: Large companies account for 6.6%, reflecting a relatively lower representation compared to medium-sized organizations.</li>
#       <li>Minimal Representation of Small Companies: Small companies make up only 1.2%, suggesting their limited presence in the dataset.</li>
#   </ul>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️On Work Year🗒️</div>

# %%
counts = df['work_year'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='work_year', palette='rocket',orient ='v', order=top_categories)
plt.title(f"Distribution of work  year", fontsize=20)
plt.ylabel('work_year', fontsize=14)
plt.xlabel("Count", fontsize=14)
plt.show()

# %%
counts = df['work_year'].value_counts()
top_categories = counts.head(10)
plt.figure(figsize=(8,8))
plt.pie(top_categories , labels = top_categories.index , 
        autopct = '%1.1f%%',startangle=90,colors=plt.cm.tab10.colors)
plt.title(f"Distribution of work year", fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️On Remote Ratio🗒️</div>

# %%
counts = df['remote_ratio'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='remote_ratio', palette='rocket',orient ='v', order=top_categories)
plt.title(f"Distribution of Remote ratio", fontsize=20)
plt.ylabel('remote_ratio', fontsize=14)
plt.xlabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>Remote Ratio 0: This is the most frequent remote ratio, with a count of approximately 10,000.</li>
#       <li>Remote Ratio 100: The second highest count, with a count of around 5,000.</li>
#       <li>Remote Ratio 50: The least frequent, with a count of approximately 200.</li>
#   </ul>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️ On Salary in USD 🗒️</div>

# %%
counts = df['salary_in_usd'].value_counts()
top_categories = counts.head(10).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='salary_in_usd', palette='rocket',orient ='v', order=top_categories)
plt.title(f"Distribution of Salary in usd", fontsize=20)
plt.ylabel('salary_in_usd', fontsize=14)
plt.xlabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>Most Frequent Salary: The highest bar in the chart indicates that the most frequent salary range is between 150,000 and 160,000 USD.</li>
#       <li>Decreasing Frequency: As the salary range increases, the frequency of occurrence decreases, suggesting that the number of individuals earning higher salaries is lower.</li>
#       <li>Salary Distribution: The chart displays a right-skewed distribution, meaning a majority of the data points (salaries) fall on the lower end of the range, with a smaller portion of individuals earning higher salaries.</li>
#       <li>Data Interpretation: The chart helps understand the spread of salaries within a dataset. The pattern observed indicates that the salary distribution is not uniform and is likely influenced by factors such as job roles, experience, and industry.
#
# </li>
#   </ul>

# %% [markdown]
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>Performing <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">Bivariate <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Analysis </strong></strong></strong></h1></header>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Trend Over Year🗒️</div>

# %%
plt.figure(figsize = (10,6))
salary_trend = df[['salary_in_usd', 'work_year']].sort_values(by = 'work_year')
p = sns.lineplot(data =salary_trend ,x = 'work_year', y = 'salary_in_usd', marker = 'o', color='Blue', markersize=8 )
plt.title('Salary Trend Over The Time', fontsize=20, fontweight='bold')
p.set_facecolor("#f4f4f4")
plt.legend(['salary_in_usd'], loc='best', fontsize=14)
p.grid(False)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>The salary trend shows an overall increase over time.</li>
#       <li>The salary started at around 100000 in 2020 and increased to around 150000 in 2023.</li>
#       <li>There was a dip in salary in 2021, but it rebounded in 2022.</li>
#       <li>The salary seems to have stabilized in 2023 and 2024.</li>
#   </ul>
# </div>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Trend Over Year With respect to company size🗒️</div>

# %%
plt.figure(figsize = (10,6))
p = sns.lineplot(data =df ,x = 'work_year', y = 'salary_in_usd', hue = 'company_size',marker = 'o', color='purple')
plt.title('Salary Trend Over The Time wrt company-size', fontsize=20, fontweight='bold')
plt.legend(['salary_in_usd'], loc='best', fontsize=14)
p.grid(False)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>This graph suggests that average salaries have been increasing over time.</li>
#       <li>The salary trends for different company sizes may be different, although not explicitly defined in the graph.</li>
#       <li>The average salary has the highest variation compared to the salaries for specific company sizes.</li>
#
#   </ul>
# </div>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Trends Over Experience Level 🗒️</div>

# %%
exp_salary = df.groupby('experience_level')['salary_in_usd'].mean()
plt.figure(figsize = (10,6))
ax = sns.barplot(x = exp_salary.index, y = exp_salary.values, palette = 'rocket')
plt.title('Average Salary by Experience Level', fontsize=12, fontweight='bold')
plt.xlabel('Experience Level', fontsize=12, fontweight='bold')
plt.ylabel('Average Salary (USD)', fontsize=12, fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Salary (USD)')

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>Director: The highest average salary at around 195,000.</li>
#       <li>Expert: The second highest average salary at around 165,000.</li>
#       <li>Intermediate: The third highest average salary at around 125,000.</li>
#       <li>Junior: The lowest average salary at around 90,000.</li>
#
#   </ul>
# </div>

# %%
plt.figure(figsize = (10,6))
salary_trend = df[['salary_in_usd', 'experience_level']].sort_values(by = 'experience_level')
p = sns.lineplot(data =salary_trend ,x = 'experience_level', y = 'salary_in_usd', marker = 'o', color='Blue', markersize=8 )
plt.title('Salary Trend Over Experence Level', fontsize=20, fontweight='bold')
p.set_facecolor("#f4f4f4")
plt.legend(['salary_in_usd'], loc='best', fontsize=14)
p.grid(False)
plt.show()

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Trends Over Employment_Type 🗒️</div>

# %%
exp_salary = df.groupby('employment_type')['salary_in_usd'].mean().sort_values()
plt.figure(figsize = (10,6))
ax = sns.barplot(x = exp_salary.index, y = exp_salary.values, palette = 'rocket')
plt.title('Average Salary by Employment_Type', fontsize=12, fontweight='bold')
plt.xlabel('Employment_Type', fontsize=12, fontweight='bold')
plt.ylabel('Average Salary (USD)', fontsize=12, fontweight='bold')
plt.show()

# %%
plt.figure(figsize = (10,6))
salary_trend = df[['salary_in_usd', 'employment_type']].sort_values(by = 'salary_in_usd')
p = sns.lineplot(data =salary_trend ,x = 'employment_type', y = 'salary_in_usd', marker = 'o', color='Blue', markersize=8 )
plt.title('Salary Trend Over Employment_Type', fontsize=20, fontweight='bold')
p.set_facecolor("#f4f4f4")
plt.legend(['salary_in_usd'], loc='best', fontsize=14)
p.grid(False)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>The salary trend over employment type shows a general decrease in salary from full-time to freelance, followed by an increase in salary for contract positions.
# </li>
#       <li>Full-time positions have the highest average salary, followed by part-time positions.</li>
#       <li>Freelance positions have the lowest average salary, followed by contract positions.</li>
#       <li>The spread of salaries is wider for full-time and part-time positions, compared to freelance and contract positions. This suggests that there is more variability in salaries for full-time and part-time positions.</li>
#       <li>Overall, the graph suggests that there is a relationship between employment type and salary, with full-time positions generally commanding the highest salaries. However, there is also a significant amount of variation within each employment type.</li>
#
#   </ul>
# </div>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Trends Over Job title 🗒️</div>

# %%
exp_salary = df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending = False).head(10)
plt.figure(figsize = (10,6))
ax = sns.barplot(x = exp_salary.index, y = exp_salary.values, palette = 'rocket')
plt.title('Top 10 Job titles based on Average Salary', fontsize=12, fontweight='bold')
plt.xticks(rotation = 90)
plt.xlabel('Job title', fontsize=12, fontweight='bold')
plt.ylabel('Average Salary (USD)', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Trends Over Remote ratio 🗒️</div>

# %%
exp_salary = df.groupby('remote_ratio')['salary_in_usd'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    x=exp_salary.index, 
    y=exp_salary.values, 
    palette='rocket'
)
plt.title('Average Salary by Remote Ratio', fontsize=14, fontweight='bold')
plt.xlabel('Remote Ratio (%)', fontsize=12, fontweight='bold')
plt.ylabel('Average Salary (USD)', fontsize=12, fontweight='bold')

plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>It's possible that in-person roles command higher salaries due to factors like higher demand or specific industry requirements.</li>
#       <li>The decrease in average salary for 50% remote roles could be due to a more competitive market or a broader range of skill sets and experience levels.
# </li>
#       <li>The increase in average salary for fully remote roles could be driven by factors like higher demand for remote workers or the need for specialized skills in remote-first environments.</li>
#
#
#   </ul>
# </div>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Trends Over Company Location 🗒️</div>

# %%
exp_salary = df.groupby('company_location')['salary_in_usd'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    x=exp_salary.index, 
    y=exp_salary.values, 
    palette='rocket'
)
plt.title('Average Salary by Company Locations', fontsize=14, fontweight='bold')
plt.xlabel('Compsny Location', fontsize=12, fontweight='bold')
plt.ylabel('Average Salary (USD)', fontsize=12, fontweight='bold')

plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>Qatar (QA) has the highest average salary at approximately 300,000 USD.</li>
#       <li>Israel (IL) has the second-highest average salary at approximately 220,000 USD.
# </li>
#       <li>Puerto Rico (PR) has the third-highest average salary at approximately 170,000 USD.</li>
#       <li>United States (US) has the fourth-highest average salary at approximately 160,000 USD.</li>
#      <li>New Zealand (NZ) has the fifth-highest average salary at approximately 150,000 USD.</li>
#       <li>Canada (CA) has the sixth-highest average salary at approximately 150,000 USD.
# </li>
#       <li>Egypt (EG) has the seventh-highest average salary at approximately 140,000 USD.
# </li>
#       <li>Saudi Arabia (SA) has the eighth-highest average salary at approximately 150,000 USD.
# </li>
#       <li>Australia (AU) has the ninth-highest average salary at approximately 130,000 USD.
# </li>
#       <li>Mexico (MX) has the tenth-highest average salary at approximately 130,000 USD.
# </li>
#   </ul>
# </div>

# %% [markdown]
# ## <div style="text-align: center; background: #640D5F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1.5; border-radius: 50% 50% 50% 50%  / 100px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">🗒️Salary Distribution for DS Profesionals 🗒️</div>

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(df['salary_in_usd'], kde=True, color='#c44e52', bins=20, ax=ax)
ax.set_title('Salary Distribution for Data Science Professionals', fontsize=14, fontweight='bold')
ax.set_xlabel('Salary (USD)', fontsize=12, fontweight='bold')
ax.set_ylabel('Frequency', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #f9f9f9; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h3 style="color: #4CAF50; text-align: center;">Observations</h3>
#   <ul>
#       <li>The distribution is skewed to the right, indicating a high concentration of data science professionals with lower salaries and a smaller number of individuals with significantly higher salaries.</li>
#       <li>The peak of the distribution occurs around the 150,000 USD mark, suggesting a significant number of data science professionals earn salaries within this range.
# </li>
#       <li>The presence of a long tail extending towards higher salaries signifies the potential for significant earnings in the data science field.</li>
#
#   </ul>
# </div>

# %% [markdown]
# # <header><h1 style="color:#4C0033;font-size:50px;font-family:Verdana;text-align:center;"><strong>The <strong style="color:#AF0171;font-size:35px;font-family:Verdana;">Author's <BR><strong style="color:#E80F88;font-size:70px;font-family:Verdana;">Message </strong></strong></strong></h1></header>
# <div style="background-color:white;font-size:15px;font-family:Verdana;border-style: solid;border-color: #AF0171;border-width:4px;padding:10px;margin: 1px;color:#240A34;overflow:hidden">
# <strong>💡 Thank you for exploring this notebook!</strong> 💬 I truly appreciate your time and interest. If you found this notebook insightful or helpful, your feedback means the world to me! 🚀
#
# <strong>💬 Have suggestions, questions, or insights?</strong>
# Feel free to share them in the comments below! I’m always eager to hear your thoughts and learn from the amazing Kaggle community. Together, we can refine this analysis and uncover new possibilities.
#
# <strong>👍 If you enjoyed this notebook, a simple upvote goes a long way.</strong> It not only motivates me but also helps others in the Kaggle community discover valuable content.
#
# ✨ <strong>Let’s keep learning and innovating!</strong>
# Wishing you the best on your data science journey. Thank you for being part of this community, and happy Kaggling!
